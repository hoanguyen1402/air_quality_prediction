# %%
import requests
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime
import seaborn as sns
import plotly.express as px

# %%
# Specify the URL of the API endpoint for retrieving information about fish species.
#Code: a17ac515f9b6411393c923e7abd376f5
url="https://air-quality-api.open-meteo.com/v1/air-quality?latitude=21.0285&longitude=105.8542&start_date=2024-05-01&end_date=2024-06-01&hourly=pm10,pm2_5,carbon_monoxide,nitrogen_dioxide,ozone,sulphur_dioxide"
url1="https://air-quality-api.open-meteo.com/v1/air-quality?latitude=21.0285&longitude=105.8542&start_date=2024-06-01&end_date=2024-07-01&hourly=pm10,pm2_5,carbon_monoxide,nitrogen_dioxide,ozone,sulphur_dioxide"
url2="https://air-quality-api.open-meteo.com/v1/air-quality?latitude=21.0285&longitude=105.8542&start_date=2024-07-01&end_date=2024-08-01&hourly=pm10,pm2_5,carbon_monoxide,nitrogen_dioxide,ozone,sulphur_dioxide"
url3="https://air-quality-api.open-meteo.com/v1/air-quality?latitude=21.0285&longitude=105.8542&start_date=2024-08-01&end_date=2024-09-01&hourly=pm10,pm2_5,carbon_monoxide,nitrogen_dioxide,ozone,sulphur_dioxide"
url4="https://air-quality-api.open-meteo.com/v1/air-quality?latitude=21.0285&longitude=105.8542&start_date=2024-09-01&end_date=2024-10-01&hourly=pm10,pm2_5,carbon_monoxide,nitrogen_dioxide,ozone,sulphur_dioxide"
url5="https://air-quality-api.open-meteo.com/v1/air-quality?latitude=21.0285&longitude=105.8542&start_date=2024-10-01&end_date=2024-11-01&hourly=pm10,pm2_5,carbon_monoxide,nitrogen_dioxide,ozone,sulphur_dioxide"
url6="https://air-quality-api.open-meteo.com/v1/air-quality?latitude=21.0285&longitude=105.8542&start_date=2024-11-01&end_date=2024-12-01&hourly=pm10,pm2_5,carbon_monoxide,nitrogen_dioxide,ozone,sulphur_dioxide"
url7="https://air-quality-api.open-meteo.com/v1/air-quality?latitude=21.0285&longitude=105.8542&start_date=2024-12-01&end_date=2025-01-01&hourly=pm10,pm2_5,carbon_monoxide,nitrogen_dioxide,ozone,sulphur_dioxide"
url8="https://air-quality-api.open-meteo.com/v1/air-quality?latitude=21.0285&longitude=105.8542&start_date=2025-01-01&end_date=2025-02-01&hourly=pm10,pm2_5,carbon_monoxide,nitrogen_dioxide,ozone,sulphur_dioxide"
url9="https://air-quality-api.open-meteo.com/v1/air-quality?latitude=21.0285&longitude=105.8542&start_date=2025-02-01&end_date=2025-03-01&hourly=pm10,pm2_5,carbon_monoxide,nitrogen_dioxide,ozone,sulphur_dioxide"
url10="https://air-quality-api.open-meteo.com/v1/air-quality?latitude=21.0285&longitude=105.8542&start_date=2025-03-01&end_date=2025-04-01&hourly=pm10,pm2_5,carbon_monoxide,nitrogen_dioxide,ozone,sulphur_dioxide"
url11="https://air-quality-api.open-meteo.com/v1/air-quality?latitude=21.0285&longitude=105.8542&start_date=2025-04-01&end_date=2025-05-01&hourly=pm10,pm2_5,carbon_monoxide,nitrogen_dioxide,ozone,sulphur_dioxide"
url12="https://air-quality-api.open-meteo.com/v1/air-quality?latitude=21.0285&longitude=105.8542&start_date=2025-05-01&end_date=2025-06-01&hourly=pm10,pm2_5,carbon_monoxide,nitrogen_dioxide,ozone,sulphur_dioxide"

# %%
#Parse JSON data from 08/02/2024 to 08/03/2024
data = requests.get(url)
results = json.loads(data.text)
#Parse JSON data from 08/01/2024 to 08/02/2024
data2 = requests.get(url2)
results2 = json.loads(data2.text)
#Parse JSON data from 08/12/2023 to 08/01/2024
data3 = requests.get(url3)
results3 = json.loads(data3.text)
#Parse JSON data from 08/11/2023 to 08/12/2023
data4 = requests.get(url4)
results4 = json.loads(data4.text)
#Parse JSON data from 08/10/2023 to 08/11/2023
data5 = requests.get(url5)
results5 = json.loads(data5.text)
#Parse JSON data from 08/09/2023 to 08/10/2023
data6 = requests.get(url6)
results6 = json.loads(data6.text)
#Parse JSON data from 08/08/2023 to 08/09/2023
data7 = requests.get(url7)
results7 = json.loads(data7.text)
#Parse JSON data from 08/07/2023 to 08/08/2023
data8 = requests.get(url8)
results8 = json.loads(data8.text)
#Parse JSON data from 08/06/2023 to 08/07/2023
data9 = requests.get(url9)
results9 = json.loads(data9.text)
#Parse JSON data from 08/05/2023 to 08/06/2023
data10 = requests.get(url10)
results10 = json.loads(data10.text)
#Parse JSON data from 08/04/2023 to 08/05/2023
data11 = requests.get(url11)
results11 = json.loads(data11.text)
#Parse JSON data from 08/03/2023 to 08/04/2023
data12 = requests.get(url12)
results12 = json.loads(data12.text)

# %%
datasets = [results, results2, results3, results4, results5, results6,
            results7, results8, results9, results10, results11, results12]

all_data_air = []

for i, res in enumerate(datasets, start=1):
    if "hourly" in res:
        print(f" Dữ liệu tháng {i} có {len(res['hourly']['time'])} mẫu")
        df_part = pd.DataFrame(res["hourly"])  # lấy phần hourly ra
        all_data_air.append(df_part)
    else:
        print(f" Không có key 'hourly' trong kết quả {i}")

# Gộp tất cả các DataFrame lại
if all_data_air:
    air_df = pd.concat(all_data_air, ignore_index=True)
    print("Tổng số dòng dữ liệu:", len(air_df))
    print(air_df.head())
else:
    print(" Không có dữ liệu nào để ghép.")
# Out:
#  Dữ liệu tháng 1 có 768 mẫu
#  Dữ liệu tháng 2 có 768 mẫu
#  Dữ liệu tháng 3 có 768 mẫu
#  Dữ liệu tháng 4 có 744 mẫu
#  Dữ liệu tháng 5 có 768 mẫu
#  Dữ liệu tháng 6 có 744 mẫu
#  Dữ liệu tháng 7 có 768 mẫu
#  Dữ liệu tháng 8 có 768 mẫu
#  Dữ liệu tháng 9 có 696 mẫu
#  Dữ liệu tháng 10 có 768 mẫu
#  Dữ liệu tháng 11 có 744 mẫu
#  Dữ liệu tháng 12 có 768 mẫu
# Tổng số dòng dữ liệu: 9072
#                time  pm10  pm2_5  carbon_monoxide  nitrogen_dioxide  ozone  \
# 0  2024-05-01T00:00  43.4   29.8            457.0              10.4   79.0
# 1  2024-05-01T01:00  41.8   28.8            467.0              10.5   79.0
# 2  2024-05-01T02:00  43.4   29.8            481.0              10.5   78.0
# 3  2024-05-01T03:00  44.5   30.5            491.0              10.4   81.0
# 4  2024-05-01T04:00  48.4   33.1            492.0               9.9   89.0
#
#    sulphur_dioxide
# 0             16.5
# 1             17.1
# 2             17.8
# 3             18.5
# 4             18.9

# %%
urlweath='https://archive-api.open-meteo.com/v1/archive?latitude=21.0285&longitude=105.8542&start_date=2024-05-01&end_date=2024-06-01&hourly=temperature_2m,relative_humidity_2m,precipitation,windspeed_10m,winddirection_10m,surface_pressure'
urlweath1='https://archive-api.open-meteo.com/v1/archive?latitude=21.0285&longitude=105.8542&start_date=2024-06-01&end_date=2024-07-01&hourly=temperature_2m,relative_humidity_2m,precipitation,windspeed_10m,winddirection_10m,surface_pressure'
urlweath2='https://archive-api.open-meteo.com/v1/archive?latitude=21.0285&longitude=105.8542&start_date=2024-07-01&end_date=2024-08-01&hourly=temperature_2m,relative_humidity_2m,precipitation,windspeed_10m,winddirection_10m,surface_pressure'
urlweath3='https://archive-api.open-meteo.com/v1/archive?latitude=21.0285&longitude=105.8542&start_date=2024-08-01&end_date=2024-09-01&hourly=temperature_2m,relative_humidity_2m,precipitation,windspeed_10m,winddirection_10m,surface_pressure'
urlweath4='https://archive-api.open-meteo.com/v1/archive?latitude=21.0285&longitude=105.8542&start_date=2024-09-01&end_date=2024-10-01&hourly=temperature_2m,relative_humidity_2m,precipitation,windspeed_10m,winddirection_10m,surface_pressure'
urlweath5='https://archive-api.open-meteo.com/v1/archive?latitude=21.0285&longitude=105.8542&start_date=2024-10-01&end_date=2024-11-01&hourly=temperature_2m,relative_humidity_2m,precipitation,windspeed_10m,winddirection_10m,surface_pressure'
urlweath6='https://archive-api.open-meteo.com/v1/archive?latitude=21.0285&longitude=105.8542&start_date=2024-11-01&end_date=2024-12-01&hourly=temperature_2m,relative_humidity_2m,precipitation,windspeed_10m,winddirection_10m,surface_pressure'
urlweath7='https://archive-api.open-meteo.com/v1/archive?latitude=21.0285&longitude=105.8542&start_date=2024-12-01&end_date=2025-01-01&hourly=temperature_2m,relative_humidity_2m,precipitation,windspeed_10m,winddirection_10m,surface_pressure'
urlweath8='https://archive-api.open-meteo.com/v1/archive?latitude=21.0285&longitude=105.8542&start_date=2025-01-01&end_date=2025-02-01&hourly=temperature_2m,relative_humidity_2m,precipitation,windspeed_10m,winddirection_10m,surface_pressure'
urlweath9='https://archive-api.open-meteo.com/v1/archive?latitude=21.0285&longitude=105.8542&start_date=2025-02-01&end_date=2025-03-01&hourly=temperature_2m,relative_humidity_2m,precipitation,windspeed_10m,winddirection_10m,surface_pressure'
urlweath10='https://archive-api.open-meteo.com/v1/archive?latitude=21.0285&longitude=105.8542&start_date=2025-03-01&end_date=2025-04-01&hourly=temperature_2m,relative_humidity_2m,precipitation,windspeed_10m,winddirection_10m,surface_pressure'
urlweath11='https://archive-api.open-meteo.com/v1/archive?latitude=21.0285&longitude=105.8542&start_date=2025-04-01&end_date=2025-05-01&hourly=temperature_2m,relative_humidity_2m,precipitation,windspeed_10m,winddirection_10m,surface_pressure'
urlweath12='https://archive-api.open-meteo.com/v1/archive?latitude=21.0285&longitude=105.8542&start_date=2025-05-01&end_date=2025-06-01&hourly=temperature_2m,relative_humidity_2m,precipitation,windspeed_10m,winddirection_10m,surface_pressure'

# %%
# Make an HTTP GET request to the specified URL and store the response in the data variable.
data_w = requests.get(urlweath)
results_w = json.loads(data_w.text)
# Make an HTTP GET request to the specified URL and store the response in the data variable.
data_w2 = requests.get(urlweath2)
results_w2 = json.loads(data_w2.text)
# Make an HTTP GET request to the specified URL and store the response in the data variable.
data_w3 = requests.get(urlweath3)
results_w3 = json.loads(data_w3.text)
# Make an HTTP GET request to the specified URL and store the response in the data variable.
data_w4 = requests.get(urlweath4)
results_w4 = json.loads(data_w4.text)
# Make an HTTP GET request to the specified URL and store the response in the data variable.
data_w5 = requests.get(urlweath5)
results_w5 = json.loads(data_w5.text)
# Make an HTTP GET request to the specified URL and store the response in the data variable.
data_w6 = requests.get(urlweath6)
results_w6 = json.loads(data_w6.text)
# Make an HTTP GET request to the specified URL and store the response in the data variable.
data_w7 = requests.get(urlweath7)
results_w7 = json.loads(data_w7.text)
# Make an HTTP GET request to the specified URL and store the response in the data variable.
data_w8 = requests.get(urlweath8)
results_w8 = json.loads(data_w8.text)
# Make an HTTP GET request to the specified URL and store the response in the data variable.
data_w9 = requests.get(urlweath9)
results_w9 = json.loads(data_w9.text)
# Make an HTTP GET request to the specified URL and store the response in the data variable.
data_w10 = requests.get(urlweath10)
results_w10 = json.loads(data_w10.text)
# Make an HTTP GET request to the specified URL and store the response in the data variable.
data_w11 = requests.get(urlweath11)
results_w11 = json.loads(data_w11.text)
# Make an HTTP GET request to the specified URL and store the response in the data variable.
data_w12 = requests.get(urlweath12)
results_w12 = json.loads(data_w12.text)

# %%
datasets_w = [results_w, results_w2, results_w3, results_w4, results_w5, results_w6,
            results_w7, results_w8, results_w9, results_w10, results_w11, results_w12]

all_data_weather = []

for i, res in enumerate(datasets_w, start=1):
    if "hourly" in res:
        print(f"Dữ liệu tháng {i} có {len(res['hourly']['time'])} mẫu")
        df_part = pd.DataFrame(res["hourly"])  # lấy phần hourly ra
        all_data_weather.append(df_part)
    else:
        print(f"Không có key 'hourly' trong kết quả {i}")

# Gộp tất cả các DataFrame lại
if all_data_weather:
    weather_df = pd.concat(all_data_weather, ignore_index=True)
    print(" Tổng số dòng dữ liệu:", len(weather_df))
    print(weather_df.head())
else:
    print(" Không có dữ liệu nào để ghép.")
# Out:
# Dữ liệu tháng 1 có 768 mẫu
# Dữ liệu tháng 2 có 768 mẫu
# Dữ liệu tháng 3 có 768 mẫu
# Dữ liệu tháng 4 có 744 mẫu
# Dữ liệu tháng 5 có 768 mẫu
# Dữ liệu tháng 6 có 744 mẫu
# Dữ liệu tháng 7 có 768 mẫu
# Dữ liệu tháng 8 có 768 mẫu
# Dữ liệu tháng 9 có 696 mẫu
# Dữ liệu tháng 10 có 768 mẫu
# Dữ liệu tháng 11 có 744 mẫu
# Dữ liệu tháng 12 có 768 mẫu
#  Tổng số dòng dữ liệu: 9072
#                time  temperature_2m  relative_humidity_2m  precipitation  \
# 0  2024-05-01T00:00            25.2                    75            0.0
# 1  2024-05-01T01:00            26.8                    72            0.0
# 2  2024-05-01T02:00            27.7                    69            0.0
# 3  2024-05-01T03:00            28.9                    66            0.0
# 4  2024-05-01T04:00            29.3                    66            0.0
#
#    windspeed_10m  winddirection_10m  surface_pressure
# 0           19.2                 17            1004.3
# ...

# %%
air_df["time"] = pd.to_datetime(air_df["time"])
weather_df["time"] = pd.to_datetime(weather_df["time"])
# Gộp hai bảng theo cột 'time'
merged_df = pd.merge(air_df, weather_df, on="time", how="inner")
print(merged_df.head())
# Out:
#                  time  pm10  pm2_5  carbon_monoxide  nitrogen_dioxide  ozone  \
# 0 2024-05-01 00:00:00  43.4   29.8            457.0              10.4   79.0
# 1 2024-05-01 01:00:00  41.8   28.8            467.0              10.5   79.0
# 2 2024-05-01 02:00:00  43.4   29.8            481.0              10.5   78.0
# 3 2024-05-01 03:00:00  44.5   30.5            491.0              10.4   81.0
# 4 2024-05-01 04:00:00  48.4   33.1            492.0               9.9   89.0
#
#    sulphur_dioxide  temperature_2m  relative_humidity_2m  precipitation  \
# 0             16.5            25.2                    75            0.0
# 1             17.1            26.8                    72            0.0
# 2             17.8            27.7                    69            0.0
# 3             18.5            28.9                    66            0.0
# 4             18.9            29.3                    66            0.0
#
#    windspeed_10m  winddirection_10m  surface_pressure
# ...

# %%
merged_df.head(10)
# Out:
#                  time  pm10  pm2_5  carbon_monoxide  nitrogen_dioxide  ozone  \
# 0 2024-05-01 00:00:00  43.4   29.8            457.0              10.4   79.0
# 1 2024-05-01 01:00:00  41.8   28.8            467.0              10.5   79.0
# 2 2024-05-01 02:00:00  43.4   29.8            481.0              10.5   78.0
# 3 2024-05-01 03:00:00  44.5   30.5            491.0              10.4   81.0
# 4 2024-05-01 04:00:00  48.4   33.1            492.0               9.9   89.0
# 5 2024-05-01 05:00:00  53.4   36.4            490.0               9.3   99.0
# 6 2024-05-01 06:00:00  58.2   39.7            492.0               9.0  107.0
# 7 2024-05-01 07:00:00  64.0   43.7            494.0               8.9  112.0
# 8 2024-05-01 08:00:00  73.6   50.1            500.0               9.1  116.0
# 9 2024-05-01 09:00:00  81.5   55.4            534.0              10.8  115.0
#
#    sulphur_dioxide  temperature_2m  relative_humidity_2m  precipitation  \
# ...

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9552 entries, 0 to 9551
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   time                  9552 non-null   datetime64[ns]
#  1   pm10                  9552 non-null   float64
#  2   pm2_5                 9552 non-null   float64
#  3   carbon_monoxide       9552 non-null   float64
#  4   nitrogen_dioxide      9552 non-null   float64
#  5   ozone                 9552 non-null   float64
#  6   sulphur_dioxide       9552 non-null   float64
#  7   temperature_2m        9552 non-null   float64
#  8   relative_humidity_2m  9552 non-null   int64
#  9   precipitation         9552 non-null   float64
#  10  windspeed_10m         9552 non-null   float64
#  11  winddirection_10m     9552 non-null   int64
#  12  surface_pressure      9552 non-null   float64
# dtypes: datetime64[ns](1), float64(10), int64(2)
# memory usage: 970.3 KB

# %% [markdown]
# Air Quality columns
# CO: Carbon Monoxide (mg/m^3)
# NO2: Nitrogen Dioxide (ug/m^3)
# O3: Ozone (ppb)
# PM10: Particulate Matter 10 (ug/m^3)
# PM25: Particulate Matter 2.5 (ug/m^3)
# SO2: Sulfur Dioxide (ppb)
#
# Weather columns
# Precipitation: Precipitation (mm)
# Surface Pressure: Atmospheric Pressure (hPa)
# Relative Humidity 2m: Humidity (%)
# Temperature 2m: Temperature (°C)
# Wind Speed 10m: Wind Speed (m/s)
# Wind Direction 10m: Wind Direction (m/s)

# %%
merged_df.to_csv('hanoi_weather_data.csv')
